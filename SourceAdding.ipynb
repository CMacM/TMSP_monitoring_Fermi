# %%
import mkLightCurve
from astropy import units
from astropy.coordinates import SkyCoord
# Out:
# This is make4FGLxml version 01r05.
# The default diffuse model files and names are for pass 8 and 4FGL and assume you have v11r5p3 of the Fermi Science Tools or higher.

# %% [markdown]
# # PSR J18245-2452

# %%
mkLightCurve.GenFileList(mkLightCurve.J18245)
mkLightCurve.SourceModel(mkLightCurve.J18245)

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J18245)

# %%
mkLightCurve.plot_curve(source='J1023', mode='paper')

# %% [markdown]
# # PSR J1723-2837

# %%
c = SkyCoord('17h23m23s', '-28d37m57s', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC

# %%
mkLightCurve.GenFileList(mkLightCurve.J1723)
mkLightCurve.SourceModel(mkLightCurve.J1723)

# %% [markdown]
# # PSR J2215+51

# %%
c = SkyCoord('22h15m33s', '51d35m36', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC

# %%
mkLightCurve.GenFileList(mkLightCurve.J2215)
mkLightCurve.SourceModel(mkLightCurve.J2215)

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J2215)

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J2215)

# %% [markdown]
# # PSR J1544-1125

# %%
c = SkyCoord('15h44m14s', '-11d24m42s', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC

# %%
mkLightCurve.GenFileList(mkLightCurve.J1544)
mkLightCurve.SourceModel(mkLightCurve.J1544)

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J1544)

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J1544)

# %% [markdown]
# # PSR J0212+5320

# %%
c = SkyCoord('02h12m10s', '53d20m38s', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC

# %%
mkLightCurve.GenFileList(mkLightCurve.J0212)
mkLightCurve.SourceModel(mkLightCurve.J0212)

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J0212)

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J0212)

# %%
def add_new_source():
    full_name = raw_input('Enter name in format -> PSR J 00 00 00 +/-00 00 00')
    name_list = full_name.split()
    tag = name_list[0]
    calendar = name_list[1]
    RAh = name_list[2]
    RAm = name_list[3]
    RAs = name_list[4]
    DECd = name_list[5]
    DECm = name_list[6]
    DECs = name_list[7]
    catalogue_name = tag+' '+calendar+RAh+RAm+DECd+DECm
    name = calendar+RAh+RAm
    print catalogue_name
    
    c = SkyCoord(RAh+'h'+RAm+'m'+RAs+'s', DECd+'d'+DECm+'m'+DECs+'s', frame='icrs')
    RA = round(c.ra.deg, 3)
    DEC = round(c.dec.deg, 3)
    print 'RA = ', RA, 'DEC = ', DEC
    
    return {'name' : name, 'model_name' : 'plchldr', 'xcoord' : RA, 'ycoord' : DEC, 'rec_binsz' : 4000000, 'catalogue_name' : catalogue_name}

# %%
add_new_source()

# %%
source_list = [{'name' : 'J1023', 'model_name' : '4FGL J1023.7+0038', 'xcoord' : 155.946, 'ycoord' : 0.645, 'rec_binsz' : 2000000, 'catalogue_name' : 'PSR J1023+0038'},
{'name' : 'J12270', 'model_name' : '4FGL J1228.0-4853', 'xcoord' : 186.995, 'ycoord' : -48.8952, 'rec_binsz' : 4000000, 'catalogue_name' : 'XSS J12270-4859'},
{'name' : 'J18245', 'model_name' : '4FGL J1824.6-2452', 'xcoord' : 276.135, 'ycoord' : -24.8688, 'rec_binsz' : 12000000, 'catalogue_name' : 'IGR J18245-2452'},
{'name' : 'J0427', 'model_name' : '4FGL J0427.8-6704', 'xcoord' : 66.958, 'ycoord' : -67.078, 'rec_binsz' : 4000000, 'catalogue_name' : '3FGL J0427-6704'},
{'name' : 'J1723', 'model_name' : 'plchldr', 'xcoord' : 260.846, 'ycoord' : -28.633, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J1723-2837'},
{'name' : 'J2215', 'model_name' : '4FGL J2215.6+5135', 'xcoord' : 333.888, 'ycoord' : 51.593, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J2215+5135'},
{'name' : 'J1544', 'model_name' : '4FGL J1544.5-1126', 'xcoord' : 236.058, 'ycoord' : -11.412, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J1544-1125'},
{'name' : 'J0212', 'model_name' : '4FGL J0212.1+5321', 'xcoord' : 33.042, 'ycoord' : 53.344, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J0212+5320'}]

# %%
dict(name='J1023')

# %% [markdown]
# # PSR J1417-4404

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.GenFileList(mkLightCurve.J1417)
mkLightCurve.SourceModel(mkLightCurve.J1417)

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J1417)

# %% [markdown]
# # CXOU J110926-650224

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.GenFileList(mkLightCurve.J1109)
mkLightCurve.SourceModel(mkLightCurve.J1109)

# %% [markdown]
# Not a fermi source

# %% [markdown]
# # PSR J1746-2851

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.GenFileList(mkLightCurve.J1746)
mkLightCurve.SourceModel(mkLightCurve.J1746)

# %%
mkLightCurve.CalcAllBins(poolsize=20, source=mkLightCurve.J1746)

# %%
mkLightCurve.PlotCurve(mkLightCurve.J1746)

# %% [markdown]
# # CXOGlb J174804-244641

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.gen_file_list()

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J1748')

# %%
mkLightCurve.plot_curve('J1748')

# %% [markdown]
# # IGR J17379-3747

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.gen_file_list()
mkLightCurve.source_model('J1737')

# %% [markdown]
# Not a Fermi source

# %% [markdown]
# # PSR J2339-0530

# %%
mkLightCurve.add_new_source()

# %%
#mkLightCurve.gen_file_list()
mkLightCurve.source_model('J2339')

# %%
mkLightCurve.calc_all_bins(poolsize=20, source='J2339')

# %%
mkLightCurve.plot_curve('J2339')

# %% [markdown]
# # PSR J1311-3429

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.gen_file_list()
mkLightCurve.source_model('J1311')

# %%
mkLightCurve.calc_all_bins(poolsize=20, source='J1311')

# %%
mkLightCurve.plot_curve('J1311')

# %% [markdown]
# # PSR J0251+2600

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.gen_file_list()

# %%
mkLightCurve.source_model('J0251')

# %%
mkLightCurve.calc_all_bins(poolsize=20, source='J0251')

# %%
mkLightCurve.plot_curve('J0251')

# %% [markdown]
# # PSR J1048+2339

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.gen_file_list()

# %%
mkLightCurve.source_model('J1048')

# %%
mkLightCurve.calc_all_bins(poolsize=20, source='J1048')

# %%
mkLightCurve.plot_curve('J1048')

# %% [markdown]
# # IGR J17511-3057

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J1751')

# %% [markdown]
# # PSR J1805+06

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J1805')

# %%
mkLightCurve.calc_all_bins(poolsize=20, source='J1805')

# %%
mkLightCurve.plot_curve('J1805')

# %% [markdown]
# # PSR J2129-0429

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J2129')

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J2129')

# %%
mkLightCurve.plot_curve('J2129')

# %%
mkLightCurve.export_fluxes()

# %% [markdown]
# # 4FGL J0407-5702

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J0407')

# %%
mkLightCurve.calc_all_bins(poolsize=30,source='J0407')

# %%
mkLightCurve.plot_curve('J0407')

# %% [markdown]
# # 4FGL J0935+0901

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J0935')

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J0935')

# %%
mkLightCurve.plot_curve('J0935')

# %% [markdown]
# # 4FGL J2333-5527

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J2333')

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J2333')

# %%
mkLightCurve.plot_curve('J2333')

# %% [markdown]
# # 47 Tuc W

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J0024')

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J0024')

# %%
mkLightCurve.plot_curve('J0024')

# %% [markdown]
# # XMMU J083850-282756

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J0838')

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J0838')

# %%
mkLightCurve.plot_curve('J0838')

# %% [markdown]
# # XTE J1814-338

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J1814')

# %% [markdown]
# # 4FGL J2039-5620

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J2039')

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J2039')

# %%
mkLightCurve.plot_curve('J2039')

# %% [markdown]
# # 4FGL J0940-7610

# %%
mkLightCurve.add_new_source()

# %%
mkLightCurve.source_model('J0940')
# Out:
# time -p gtselect infile=@photons.txt outfile=/home/b7009348/projects/Pulsar_Project/fermi-data/J0940_Weekly/J0940_allphotons_filtered.fits ra=145.0 dec=-76.167 rad=20.0 tmin=239557417.0 tmax=633331263.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2902.48
# user 2770.13
# sys 74.64
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=/home/b7009348/projects/Pulsar_Project/fermi-data/J0940_Weekly/J0940_allphotons_filtered.fits evtable="EVENTS" outfile="/home/b7009348/projects/Pulsar_Project/fermi-data/J0940_Weekly/J0940_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 345.34
# user 326.07
# sys 4.29
# Creating file and adding sources from 4FGL
# Extended source 4FGL J1208.5-5243e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1208.5-5243e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1208.5-5243e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J0530.0-6900e in ROI, make sure /home/b7009348/projects/Pulsar_Project/fermi-data/$(LATEXTDIR)/Templates/LMC-30DorWest.fits is the correct path to the extended template.
# Extended source 4FGL J0500.9-6945e in ROI, make sure /home/b7009348/projects/Pulsar_Project/fermi-data/$(LATEXTDIR)/Templates/LMC-FarWest.fits is the correct path to the extended template.
# Extended source 4FGL J0519.9-6845e in ROI, make sure /home/b7009348/projects/Pulsar_Project/fermi-data/$(LATEXTDIR)/Templates/LMC-Galaxy.fits is the correct path to the extended template.
# Extended source 4FGL J1501.0-6310e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1501.0-6310e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1501.0-6310e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1507.9-6228e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1507.9-6228e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1507.9-6228e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1443.0-6227e in ROI, make sure /home/b7009348/projects/Pulsar_Project/fermi-data/$(LATEXTDIR)/Templates/RCW86.fits is the correct path to the extended template.
# Extended source 4FGL J1420.3-6046e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1420.3-6046e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1420.3-6046e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1109.4-6115e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1109.4-6115e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1109.4-6115e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1213.3-6240e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1213.3-6240e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1213.3-6240e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1409.1-6121e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1409.1-6121e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1409.1-6121e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J0058.0-7245e in ROI, make sure /home/b7009348/projects/Pulsar_Project/fermi-data/$(LATEXTDIR)/Templates/SMC-Galaxy.fits is the correct path to the extended template.
# Extended source 4FGL J0531.8-6639e in ROI, make sure /home/b7009348/projects/Pulsar_Project/fermi-data/$(LATEXTDIR)/Templates/LMC-North.fits is the correct path to the extended template.
# Extended source 4FGL J1303.0-6312e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1303.0-6312e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1303.0-6312e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1355.2-6420e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1355.2-6420e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1355.2-6420e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1023.3-5747e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1023.3-5747e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1023.3-5747e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1036.3-5833e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1036.3-5833e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1036.3-5833e in ROI, with RadialDisk spatial model.
# Added 403 point sources and 17 extended sources
# If using unbinned likelihood you will need to rerun gtdiffrsp for the extended sources or rerun the makeModel function with optional argument psForce=True

# %%
mkLightCurve.calc_all_bins(poolsize=30, source='J0940')
# Out:
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w009_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w010_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w011_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w012_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w013_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w014_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w015_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w016_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w017_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w018_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w019_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w020_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w021_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w022_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w023_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w024_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w025_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w026_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w027_p202_v001.fits
#
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w028_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w029_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w030_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w031_p202_v001.fits
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w032_p202_v001.fits
#
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w033_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w034_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w035_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w036_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w037_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w038_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w039_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w040_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w041_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w042_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w043_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w044_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w045_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w046_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w047_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w048_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w049_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w050_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w051_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w052_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w053_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w054_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w055_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w056_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w057_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w058_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w059_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w060_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w061_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w062_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w063_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w064_p202_v001.fits
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w009_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w010_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w011_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w012_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w013_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w014_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w015_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w016_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w017_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w018_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w019_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w020_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w021_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w022_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w023_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w024_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w025_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w026_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w027_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w028_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w029_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w030_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w031_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w032_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w033_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w034_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w035_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w036_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w037_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w038_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w039_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w040_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w041_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w042_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w043_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w044_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w045_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w046_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w047_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w048_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w049_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w050_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w051_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w052_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w053_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_w054_p202_v001.fits
# Working on file /home/b7009348/projects/Pulsar_Project/fermi-data/Weekly_Spacecraft/weekly/spacecraft/lat_spacecraft_weekly_