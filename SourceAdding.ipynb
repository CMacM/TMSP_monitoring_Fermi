# %%
import mkLightCurve
from astropy import units
from astropy.coordinates import SkyCoord
# Out:
# This is make4FGLxml version 01r05.
# The default diffuse model files and names are for pass 8 and 4FGL and assume you have v11r5p3 of the Fermi Science Tools or higher.

# %% [markdown]
# # PSR J18245-2452

# %%
mkLightCurve.GenFileList(mkLightCurve.J18245)
mkLightCurve.SourceModel(mkLightCurve.J18245)
# Out:
# time -p gtselect infile=@photons.txt outfile=J18245_allphotons_filtered.fits ra=276.135 dec=-24.8688 rad=20.0 tmin=239557417.0 tmax=618748156.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2801.39
# user 2677.19
# sys 76.59
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J18245_allphotons_filtered.fits evtable="EVENTS" outfile="J18245_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 306.10
# user 296.35
# sys 8.60
# Creating file and adding sources from 4FGL
# ...

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J18245)
# Out:
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# ...

# %%
mkLightCurve.PlotCurve(mkLightCurve.J18245)

# %% [markdown]
# # PSR J1723-2837

# %%
c = SkyCoord('17h23m23s', '-28d37m57s', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC
# Out:
# 260.845833333 -28.6325

# %%
mkLightCurve.GenFileList(mkLightCurve.J1723)
mkLightCurve.SourceModel(mkLightCurve.J1723)
# Out:
# ...
# Creating file and adding sources from 4FGL
# Extended source 4FGL J1834.5-0846e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1834.5-0846e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1834.5-0846e in ROI, with RadialGaussian spatial model.
# Extended source 4FGL J1741.6-3917e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1741.6-3917e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1741.6-3917e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1615.3-5146e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1615.3-5146e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1615.3-5146e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1553.8-5325e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1553.8-5325e in ROI, with RadialDisk spatial model.
# Extended source 4FGL J1553.8-5325e in ROI, with RadialDisk spatial model.
# ...

# %% [markdown]
# # PSR J2215+51

# %%
c = SkyCoord('22h15m33s', '51d35m36', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC
# Out:
# 333.8875 51.5933333333

# %%
mkLightCurve.GenFileList(mkLightCurve.J2215)
mkLightCurve.SourceModel(mkLightCurve.J2215)
# Out:
# time -p gtselect infile=@photons.txt outfile=J2215_allphotons_filtered.fits ra=333.888 dec=51.593 rad=20.0 tmin=239557417.0 tmax=618748156.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2753.73
# user 2671.39
# sys 51.68
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J2215_allphotons_filtered.fits evtable="EVENTS" outfile="J2215_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 399.71
# user 389.81
# sys 5.21
# Creating file and adding sources from 4FGL
# ...

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J2215)

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J2215)

# %% [markdown]
# # PSR J1544-1125

# %%
c = SkyCoord('15h44m14s', '-11d24m42s', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC
# Out:
# 236.058333333 -11.4116666667

# %%
mkLightCurve.GenFileList(mkLightCurve.J1544)
mkLightCurve.SourceModel(mkLightCurve.J1544)
# Out:
# time -p gtselect infile=@photons.txt outfile=J1544_allphotons_filtered.fits ra=236.058 dec=-11.412 rad=20.0 tmin=239557417.0 tmax=618748156.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2446.49
# user 2317.63
# sys 61.14
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J1544_allphotons_filtered.fits evtable="EVENTS" outfile="J1544_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 294.91
# user 279.42
# sys 2.98
# Creating file and adding sources from 4FGL
# ...

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J1544)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-89ce1c37566a> in <module>()
# ----> 1 mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J1544)
#
# mkLightCurve.py in CalcAllBins(poolsize, source, binsz)
#
# /nobackup/b7009348/anaconda2/envs/fermi/lib/python2.7/multiprocessing/pool.pyc in map(self, func, iterable, chunksize)
#     251         '''
#     252         assert self._state == RUN
# --> 253         return self.map_async(func, iterable, chunksize).get()
#     254
#     255     def imap(self, func, iterable, chunksize=1):
#
# /nobackup/b7009348/anaconda2/envs/fermi/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     570             return self._value
#     571         else:
# --> 572             raise self._value
#     573
#     574     def _set(self, i, obj):
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J1544)

# %% [markdown]
# # PSR J0212+5320

# %%
c = SkyCoord('02h12m10s', '53d20m38s', frame='icrs')
RA = c.ra.deg
DEC = c.dec.deg
print RA, DEC
# Out:
# 33.0416666667 53.3438888889

# %%
mkLightCurve.GenFileList(mkLightCurve.J0212)
mkLightCurve.SourceModel(mkLightCurve.J0212)
# Out:
# time -p gtselect infile=@photons.txt outfile=J0212_allphotons_filtered.fits ra=33.042 dec=53.344 rad=20.0 tmin=239557417.0 tmax=619171923.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 3627.47
# user 2436.59
# sys 65.36
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J0212_allphotons_filtered.fits evtable="EVENTS" outfile="J0212_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 373.88
# user 298.92
# sys 4.66
# Creating file and adding sources from 4FGL
# ...

# %%
mkLightCurve.CalcAllBins(poolsize=15, source=mkLightCurve.J0212)

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J0212)

# %%
def add_new_source():
    full_name = raw_input('Enter name in format -> PSR J 00 00 00 +/-00 00 00')
    name_list = full_name.split()
    tag = name_list[0]
    calendar = name_list[1]
    RAh = name_list[2]
    RAm = name_list[3]
    RAs = name_list[4]
    DECd = name_list[5]
    DECm = name_list[6]
    DECs = name_list[7]
    catalogue_name = tag+' '+calendar+RAh+RAm+DECd+DECm
    name = calendar+RAh+RAm
    print catalogue_name
    
    c = SkyCoord(RAh+'h'+RAm+'m'+RAs+'s', DECd+'d'+DECm+'m'+DECs+'s', frame='icrs')
    RA = round(c.ra.deg, 3)
    DEC = round(c.dec.deg, 3)
    print 'RA = ', RA, 'DEC = ', DEC
    
    return {'name' : name, 'model_name' : 'plchldr', 'xcoord' : RA, 'ycoord' : DEC, 'rec_binsz' : 4000000, 'catalogue_name' : catalogue_name}

# %%
add_new_source()
# Out:
# Enter name in format -> PSR J 00 00 00 +/-00 00 00 PSR J 10 23 47 +00 38 56
# PSR J1023+0038
# RA =  155.946 DEC =  0.649
# {'catalogue_name': 'PSR J1023+0038',
#  'model_name': 'plchldr',
#  'name': 'J1023',
#  'rec_binsz': 4000000,
#  'xcoord': 155.946,
#  'ycoord': 0.649}

# %%
source_list = [{'name' : 'J1023', 'model_name' : '4FGL J1023.7+0038', 'xcoord' : 155.946, 'ycoord' : 0.645, 'rec_binsz' : 2000000, 'catalogue_name' : 'PSR J1023+0038'},
{'name' : 'J12270', 'model_name' : '4FGL J1228.0-4853', 'xcoord' : 186.995, 'ycoord' : -48.8952, 'rec_binsz' : 4000000, 'catalogue_name' : 'XSS J12270-4859'},
{'name' : 'J18245', 'model_name' : '4FGL J1824.6-2452', 'xcoord' : 276.135, 'ycoord' : -24.8688, 'rec_binsz' : 12000000, 'catalogue_name' : 'IGR J18245-2452'},
{'name' : 'J0427', 'model_name' : '4FGL J0427.8-6704', 'xcoord' : 66.958, 'ycoord' : -67.078, 'rec_binsz' : 4000000, 'catalogue_name' : '3FGL J0427-6704'},
{'name' : 'J1723', 'model_name' : 'plchldr', 'xcoord' : 260.846, 'ycoord' : -28.633, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J1723-2837'},
{'name' : 'J2215', 'model_name' : '4FGL J2215.6+5135', 'xcoord' : 333.888, 'ycoord' : 51.593, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J2215+5135'},
{'name' : 'J1544', 'model_name' : '4FGL J1544.5-1126', 'xcoord' : 236.058, 'ycoord' : -11.412, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J1544-1125'},
{'name' : 'J0212', 'model_name' : '4FGL J0212.1+5321', 'xcoord' : 33.042, 'ycoord' : 53.344, 'rec_binsz' : 4000000, 'catalogue_name' : 'PSR J0212+5320'}]
# Out:
# J12270

# %%
dict(name='J1023')
# Out:
# {'name': 'J1023'}

# %% [markdown]
# # PSR J1417-4404

# %%
mkLightCurve.add_new_source()
# Out:
# Enter name in format -> PSR J 00 00 00 +/-00 00 00 PSR J 14 17 17 -44 04 41
# PSR J1417-4404
# RA =  214.321 DEC =  -44.078
# {'catalogue_name': 'PSR J1417-4404',
#  'model_name': 'plchldr',
#  'name': 'J1417',
#  'rec_binsz': 4000000,
#  'xcoord': 214.321,
#  'ycoord': -44.078}

# %%
mkLightCurve.GenFileList(mkLightCurve.J1417)
mkLightCurve.SourceModel(mkLightCurve.J1417)
# Out:
# time -p gtselect infile=@photons.txt outfile=J1417_allphotons_filtered.fits ra=214.321 dec=-44.078 rad=20.0 tmin=239557417.0 tmax=619417212.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2528.55
# user 2400.08
# sys 66.25
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J1417_allphotons_filtered.fits evtable="EVENTS" outfile="J1417_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 320.95
# user 299.39
# sys 5.43
# Creating file and adding sources from 4FGL
# ...

# %%
mkLightCurve.PlotCurve(source=mkLightCurve.J1417)

# %% [markdown]
# # CXOU J110926-650224

# %%
mkLightCurve.add_new_source()
# Out:
# Enter name in format -> PSR J 00 00 00 +/-00 00 00 CXOU J 11 09 26 -65 02 24
# CXOU J1109-6502
# RA =  167.358 DEC =  -65.04
# {'catalogue_name': 'CXOU J1109-6502',
#  'model_name': 'plchldr',
#  'name': 'J1109',
#  'rec_binsz': 4000000,
#  'xcoord': 167.358,
#  'ycoord': -65.04}

# %%
mkLightCurve.GenFileList(mkLightCurve.J1109)
mkLightCurve.SourceModel(mkLightCurve.J1109)
# Out:
# time -p gtselect infile=@photons.txt outfile=J1109_allphotons_filtered.fits ra=167.358 dec=-65.04 rad=20.0 tmin=239557417.0 tmax=619417212.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2518.49
# user 2399.72
# sys 67.23
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J1109_allphotons_filtered.fits evtable="EVENTS" outfile="J1109_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 312.87
# user 297.99
# sys 5.22
# Creating file and adding sources from 4FGL
# ...

# %% [markdown]
# # PSR J1746-2851

# %%
mkLightCurve.add_new_source()
# Out:
# Enter name in format -> PSR J 00 00 00 +/-00 00 00 PSR J 17 46 33 -28 44 27
# PSR J1746-2844
# RA =  266.637 DEC =  -28.741
# {'catalogue_name': 'PSR J1746-2844',
#  'model_name': 'plchldr',
#  'name': 'J1746',
#  'rec_binsz': 4000000,
#  'xcoord': 266.637,
#  'ycoord': -28.741}

# %%
mkLightCurve.GenFileList(mkLightCurve.J1746)
mkLightCurve.SourceModel(mkLightCurve.J1746)
# Out:
# time -p gtselect infile=@photons.txt outfile=J1746_allphotons_filtered.fits ra=266.637 dec=-28.741 rad=20.0 tmin=239557417.0 tmax=619417212.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 2847.47
# user 2635.71
# sys 77.46
# time -p gtmktime scfile=@spacecraft.txt sctable="SC_DATA" filter="(DATA_QUAL>0)&&(LAT_CONFIG==1)" roicut=no evfile=J1746_allphotons_filtered.fits evtable="EVENTS" outfile="J1746_allphotons_gti.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 318.57
# user 304.74
# sys 9.32
# Creating file and adding sources from 4FGL
# ...

# %%
mkLightCurve.CalcAllBins(poolsize=20, source=mkLightCurve.J1746)

# %%
mkLightCurve.PlotCurve(mkLightCurve.J1746)

# %% [markdown]
# # CXOGlb J174804-244641

# %%
mkLightCurve.add_new_source()
# Out:
# Enter name in format -> PSR J 00 00 00 +/-00 00 00 CXOGlb J 17 48 04 -24 46 41
# CXOGlb J1748-2446
# RA =  267.017 DEC =  -24.778
# {'catalogue_name': 'CXOGlb J1748-2446',
#  'model_name': 'plchldr',
#  'name': 'J1748',
#  'rec_binsz': 4000000,
#  'xcoord': 267.017,
#  'ycoord': -24.778}

# %%
mkLightCurve.GenFileList(mkLightCurve.J174804)
mkLightCurve.SourceModel(mkLightCurve.J174804)
# Out:
# time -p gtselect infile=@photons.txt outfile=J1748_allphotons_filtered.fits ra=267.017 dec=-24.778 rad=20.0 tmin=239557417.0 tmax=619417212.0 emin=100.0 emax=500000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"

# %%
mkLightCurve.CalcAllBins(poolsize=20, source=mkLightCurve.J174804)
# Out:
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# ...
