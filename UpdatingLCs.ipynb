# %%
import mkLightCurve
import multiprocessing as mp
# Out:
# This is make4FGLxml version 01r05.
# The default diffuse model files and names are for pass 8 and 4FGL and assume you have v11r5p3 of the Fermi Science Tools or higher.

# %%
mkLightCurve.download_photons()
mkLightCurve.download_spacecraft()

# %%
mkLightCurve.update_fluxes(poolsize=26)
# Out:
# Source J1109 has no model name
# Source J1737 has no model name
# Source J1723 has no model name
# Source J1814 has no model name
# New data found, recalculating bin637557417.0
# New data found, recalculating bin637557417.0
# New data found, recalculating bin637557417.0
# New data found, recalculating bin637557417.0
# New data found, recalculating bin637557417.0
# New data found, recalculating bin637557417.0
#
#
#
#
#
#
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
#
# ...

# %%
mkLightCurve.update_curves(5)
# Out:
# /nobackup/b7009348/anaconda2/envs/fermi/lib/python2.7/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
mkLightCurve.export_fluxes()
