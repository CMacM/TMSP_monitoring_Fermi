# %%
import mkLightCurve
import glob
import numpy as np
data_dir = 'home/b7009348/projects/Pulsar_Project/fermi-data'
# Out:
# This is make4FGLxml version 01r05.
# The default diffuse model files and names are for pass 8 and 4FGL and assume you have v11r5p3 of the Fermi Science Tools or higher.

# %%
mkLightCurve.plot_curve(mode='paper', source='J1023')

# %%
mkLightCurve.plot_curve(source='J12270', mode='paper')

# %%
mkLightCurve.plot_curve(source='J18245', mode='paper')

# %%
mkLightCurve.plot_curve(source='J1746', mode='paper')

# %% [markdown]
# - J1023 : 1.37kpc
# - J12270 : 2.4-3.6kpc
# - J18245 : 5.5kpc + cluster

# %% [markdown]
# - 0.0-2.0kpc = 2,000,000 bins
# - 2.0-4.0kpc = 4,000,000 bins
# - 4.0-6.0kpc = 8,000,000 bins
# - 6.0+kpc or in cluster = 12,000,000 bins
#
# If there is no distance measure, use 4,000,000 as default and tune from there
