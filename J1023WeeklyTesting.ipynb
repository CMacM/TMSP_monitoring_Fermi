# %%
import mkLightCurve
import os
# Out:
# This is make4FGLxml version 01r05.
# The default diffuse model files and names are for pass 8 and 4FGL and assume you have v11r5p3 of the Fermi Science Tools or higher.

# %%
mkLightCurve.DownloadSpacecraft()
# Out:
# --2020-07-28 16:57:41--  https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/spacecraft/
# Resolving heasarc.gsfc.nasa.gov (heasarc.gsfc.nasa.gov)... 129.164.179.23, 2001:4d0:2310:150::23
# Connecting to heasarc.gsfc.nasa.gov (heasarc.gsfc.nasa.gov)|129.164.179.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ���/home/b7009348/projects/fermi-data/Weekly_Spacecraft/weekly/spacecraft/index.html���
#
#      0K .......... .......... .......... .......... ..........  312K
#     50K .......... .......... .......... .......... ..........  586K
#    100K ..                                                     20.3M=0.2s
#
# Last-modified header missing -- time-stamps turned off.
# 2020-07-28 16:57:42 (418 KB/s) - ���/home/b7009348/projects/fermi-data/Weekly_Spacecraft/weekly/spacecraft/index.html��� saved [105114]
#
# --2020-07-28 16:57:42--  https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/spacecraft/?C=N;O=D
# ...

# %%
mkLightCurve.DownloadPhotons()
# Out:
# --2020-07-28 17:05:33--  https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/photon/
# Resolving heasarc.gsfc.nasa.gov (heasarc.gsfc.nasa.gov)... 129.164.179.23, 2001:4d0:2310:150::23
# Connecting to heasarc.gsfc.nasa.gov (heasarc.gsfc.nasa.gov)|129.164.179.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ���/home/b7009348/projects/fermi-data/Weekly_Photons/weekly/photon/index.html���
#
#      0K .......... .......... .......... .......... ..........  678K
#     50K .......... .......... .......... .......... .......     578K=0.2s
#
# Last-modified header missing -- time-stamps turned off.
# 2020-07-28 17:05:34 (625 KB/s) - ���/home/b7009348/projects/fermi-data/Weekly_Photons/weekly/photon/index.html��� saved [100094]
#
# --2020-07-28 17:05:34--  https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/photon/?C=N;O=D
# Reusing existing connection to heasarc.gsfc.nasa.gov:443.
# ...

# %%
mkLightCurve.GenFileList()

# %%
os.chdir('/home/b7009348/projects/fermi-data/J1023_Weekly')
mkLightCurve.CalcAllBins(poolsize=15,source=mkLightCurve.J1023)
# Out:
# Bin 296557417.0 has been calculated
# Bin 272557417.0 has been calculated
# Bin 248557417.0 has been calculated
# Bin 240557417.0 has been calculated
# Bin 264557417.0 has been calculated
# Bin 256557417.0 has been calculated
# Bin 288557417.0 has been calculated
# Bin 280557417.0 has been calculated
# Bin 304557417.0 has been calculated
# Bin 312557417.0 has been calculated
# Bin 320557417.0 has been calculated
# Bin 328557417.0 has been calculated
# Bin 336557417.0 has been calculated
# Bin 352557417.0 has been calculated
# Bin 344557417.0 has been calculated
# Bin 274557417.0 has been calculated
# Bin 298557417.0 has been calculated
# Bin 250557417.0 has been calculated
# Bin 242557417.0 has been calculated
# Bin 282557417.0 has been calculated
# Bin 266557417.0 has been calculated
# Bin 258557417.0 has been calculated
# Bin 290557417.0 has been calculated
# Bin 306557417.0 has been calculated
# Bin 314557417.0 has been calculated
# Bin 322557417.0 has been calculated
# ...

# %%
mkLightCurve.PlotCurve(mkLightCurve.J1023)
